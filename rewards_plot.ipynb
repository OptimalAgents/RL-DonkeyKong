# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
y = data.flatten()
eval_every = 10000/1000
x = [x*eval_every for x in range(len(y))]
plt.plot(x,y)
plt.xlabel("Thousands of steps")
plt.ylabel("Reward")
plt.title("Reward value over time")
plt.ticklabel_format(style='sci', axis='x', scilimits=(0,7))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 import matplotlib.pyplot as plt
# ----> 2 y = data.flatten()
#       3 eval_every = 10000/1000
#       4 x = [x*eval_every for x in range(len(y))]
#
# NameError: name 'data' is not defined

# %%
data = np.load('eval_rewards/heuristic_actions_10000.npy')
y = data.flatten()
eval_every = 10000/1000
x = [x*eval_every for x in range(len(y))]
plt.plot(x,y)
plt.xlabel("Thousands of steps")
plt.ylabel("Reward")
plt.title("Reward value over time")
plt.ticklabel_format(style='sci', axis='x', scilimits=(0,7))
plt.show()

# %%
data = np.load('eval_rewards/jumping_over_barrels_10000.npy')
y = data.flatten()
eval_every = 10000/1000
x = [x*eval_every for x in range(len(y))]
plt.plot(x,y)
plt.xlabel("Thousands of steps")
plt.ylabel("Reward")
plt.title("Reward value over time")
plt.ticklabel_format(style='sci', axis='x', scilimits=(0,7))
plt.show()

# %%
data = np.load('eval_rewards/ladder_level_10000.npy')
y = data.flatten()
eval_every = 10000/1000
x = [x*eval_every for x in range(len(y))]
plt.plot(x,y)
plt.xlabel("Thousands of steps")
plt.ylabel("Reward")
plt.title("Reward value over time")
plt.ticklabel_format(style='sci', axis='x', scilimits=(0,7))
plt.show()

# %%
data = np.load('eval_rewards/ladder_level_stars_1000.npy')
y = data.flatten()
eval_every = 1000
x = [x*eval_every for x in range(len(y))]
plt.plot(x,y)
plt.xlabel("Steps")
plt.ylabel("Reward")
plt.title("Reward value over time")
plt.ticklabel_format(style='sci', axis='x', scilimits=(0,7))
plt.show()

# %%
data = np.load('eval_rewards/ladder_level_punish_needless_jump_10000.npy')
y = data.flatten()
eval_every = 10000/1000
x = [x*eval_every for x in range(len(y))]
plt.plot(x,y)
plt.xlabel("Thousands of steps")
plt.ylabel("Reward")
plt.title("Reward value over time")
plt.ticklabel_format(style='sci', axis='x', scilimits=(0,7))
plt.show()

# %%
data = np.load('eval_rewards/ladders_stars_level_punish_needless_jump_10000.npy')
y = data.flatten()
eval_every = 10000/1000
x = [x*eval_every for x in range(len(y))]
plt.plot(x,y)
plt.xlabel("Thousands of steps")
plt.ylabel("Reward")
plt.title("Reward value over time")
plt.ticklabel_format(style='sci', axis='x', scilimits=(0,7))
plt.show()

# %%
data = np.load('eval_rewards/level_1000.npy')
y = data.flatten()
eval_every = 1000
x = [x*eval_every for x in range(len(y))]
plt.plot(x,y)
plt.xlabel("Steps")
plt.ylabel("Reward")
plt.title("Reward value over time")
plt.ticklabel_format(style='sci', axis='x', scilimits=(0,7))
plt.show()

# %%
data = np.load('eval_rewards/punish_needles_jump_heuristic_actions_1000.npy')
y = data.flatten()
eval_every = 1000
x = [x*eval_every for x in range(len(y))]
plt.plot(x,y)
plt.xlabel("Steps")
plt.ylabel("Reward")
plt.title("Reward value over time")
plt.ticklabel_format(style='sci', axis='x', scilimits=(0,7))
plt.show()

# %%
data = np.load('eval_rewards/punish_needless_jump_1000.npy')
y = data.flatten()
eval_every = 1000
x = [x*eval_every for x in range(len(y))]
plt.plot(x,y)
plt.xlabel("Steps")
plt.ylabel("Reward")
plt.title("Reward value over time")
plt.ticklabel_format(style='sci', axis='x', scilimits=(0,7))
plt.show()

# %%
data = np.load('eval_rewards/standing_still_2000.npy')
y = data.flatten()
eval_every = 2000
x = [x*eval_every for x in range(len(y))]
plt.plot(x,y)
plt.xlabel("Steps")
plt.ylabel("Reward")
plt.title("Reward value over time")
plt.ticklabel_format(style='sci', axis='x', scilimits=(0,7))
plt.show()

# %%
data = np.load('eval_rewards/stars_1000.npy')
y = data.flatten()
eval_every = 1000
x = [x*eval_every for x in range(len(y))]
plt.plot(x,y)
plt.xlabel("Steps")
plt.ylabel("Reward")
plt.title("Reward value over time")
plt.ticklabel_format(style='sci', axis='x', scilimits=(0,7))
plt.show()

# %%
data = np.load('eval_rewards/jump_10000.npy')
y = data.flatten()
eval_every = 10000/1000
x = [x*eval_every for x in range(len(y))]
plt.plot(x,y)
plt.xlabel("Thousands of steps")
plt.ylabel("Reward")
plt.title("Reward value over time")
plt.ticklabel_format(style='sci', axis='x', scilimits=(0,7))
plt.show()

# %%
data = np.load('eval_rewards/level_10000.npy')
y = data.flatten()
eval_every = 10000/1000
x = [x*eval_every for x in range(len(y))]
plt.plot(x,y)
plt.xlabel("Thousands of steps")
plt.ylabel("Reward")
plt.title("Reward value over time")
plt.ticklabel_format(style='sci', axis='x', scilimits=(0,7))
plt.show()
